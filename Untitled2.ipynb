# %%
# Inicializamos el tablero con una configuración inicial de células
tablero = [[1, 1, 0, 0],
           [1, 0, 1, 0],
           [0, 0, 1, 1],
           [0, 1, 0, 1]]

# Creamos una función que calcule el número de vecinos vivos de una célula en una posición dada
def vecinos_vivos(tablero, fila, columna):
    vecinos_vivos = 0
    # Comprobamos si hay vecinos vivos en las posiciones adyacentes
    if fila > 0 and tablero[fila - 1][columna] == 1:
        vecinos_vivos += 1
    if fila < len(tablero) - 1 and tablero[fila + 1][columna] == 1:
        vecinos_vivos += 1
    if columna > 0 and tablero[fila][columna - 1] == 1:
        vecinos_vivos += 1
    if columna < len(tablero[0]) - 1 and tablero[fila][columna + 1] == 1:
        vecinos_vivos += 1
    if fila > 0 and columna > 0 and tablero[fila - 1][columna - 1] == 1:
        vecinos_vivos += 1
    if fila > 0 and columna < len(tablero[0]) - 1 and tablero[fila - 1][columna + 1] == 1:
        vecinos_vivos += 1
    if fila < len(tablero) - 1 and columna > 0 and tablero[fila + 1][columna - 1] == 1:
        vecinos_vivos += 1
    if fila < len(tablero) - 1 and columna < len(tablero[0]) - 1 and tablero[fila + 1][columna + 1] == 1:
        vecinos_vivos += 1
    return vecinos_vivos

# Creamos una función que calcule el estado de una célula en la siguiente iteración del juego
def estado_siguiente(tablero, fila, columna):
    # Obtenemos el número de vecinos vivos de la célula
    vecinos_vivos = vecinos_vivos(tablero, fila, columna)
    # Aplicamos las reglas del juego para determinar el estado de la célula en la siguiente iteración
    if tablero
# Out:
#   File "<ipython-input-3-f82344f8899e>", line 34
#     if tablero
#               ^
# SyntaxError: invalid syntax
