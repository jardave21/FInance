# %%
# !pip install pygame
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 21.8 MB 1.5 MB/s
# ...

# %%
import pygame
from pygame.locals import *
# Out:
# pygame 2.1.2 (SDL 2.0.16, Python 3.8.15)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
pygame.init()
# Out:
# (3, 2)

# %%
ventana = pygame.display.set_mode((800, 600))
pygame.display.set_caption("Mapa de Pokémon")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-8e771bc78e77> in <module>
# ----> 1 ventana = pygame.display.set_mode((800, 600))
#       2 pygame.display.set_caption("Mapa de Pokémon")
#
# error: No available video device
